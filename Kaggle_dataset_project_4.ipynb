# %% [markdown]
# <a href="https://colab.research.google.com/github/aditidolas05-dev/Salary-predictor-project-/blob/main/Kaggle_dataset_project_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/kaggle-preprocessed.csv (1).zip')
print (data)
print ("\n Head:")
print(data .head())


print ("\n TAIL:")
print(data.tail())
print ("\n Shape:")
print (data.shape)
print ("missing value:")
print (data. isnull ().sum())
# Out:
#       Unnamed: 0                                 Dataset_name  \
# 0              0                   Hotel Reservations Dataset
# 1              2        Most Subscribed 1000 Youtube Channels
# 2              3        Olympics 124 years Dataset(till 2020)
# 3              4                Medical Student Mental Health
# 4              5           Latest Netflix TV shows and movies
# ...          ...                                          ...
# 9153        9966                                     bankdata
# 9154        9967          Simpsons Episodes & Ratings (1989-)
# 9155        9968                           Video Game Dataset
# 9156        9969                             deberta-v3-small
# 9157        9970  Israeli Premier League - Team stats 2016-20
#
#             Author_name                                   Author_id  \
# 0            Ahsan Raza              https://www.kaggle.com/ahsan81
# 1     Mrityunjay Pathak  https://www.kaggle.com/themrityunjaypathak
# ...

# %% [markdown]
# # New Section
